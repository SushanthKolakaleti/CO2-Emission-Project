# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("../Datasets/CO2 Emissions_Canada.csv")

# %%
#head
df.head(10)
# Out:
#     Make       Model Vehicle Class  Engine Size(L)  Cylinders Transmission  \
# 0  ACURA         ILX       COMPACT             2.0          4          AS5
# 1  ACURA         ILX       COMPACT             2.4          4           M6
# 2  ACURA  ILX HYBRID       COMPACT             1.5          4          AV7
# 3  ACURA     MDX 4WD   SUV - SMALL             3.5          6          AS6
# 4  ACURA     RDX AWD   SUV - SMALL             3.5          6          AS6
# 5  ACURA         RLX      MID-SIZE             3.5          6          AS6
# 6  ACURA          TL      MID-SIZE             3.5          6          AS6
# 7  ACURA      TL AWD      MID-SIZE             3.7          6          AS6
# 8  ACURA      TL AWD      MID-SIZE             3.7          6           M6
# 9  ACURA         TSX       COMPACT             2.4          4          AS5
#
#   Fuel Type  Fuel Consumption City (L/100 km)  \
# 0         Z                               9.9
# 1         Z                              11.2
# ...

# %%
#tail
df.tail()
# Out:
#        Make        Model   Vehicle Class  Engine Size(L)  Cylinders  \
# 7380  VOLVO  XC40 T5 AWD     SUV - SMALL             2.0          4
# 7381  VOLVO  XC60 T5 AWD     SUV - SMALL             2.0          4
# 7382  VOLVO  XC60 T6 AWD     SUV - SMALL             2.0          4
# 7383  VOLVO  XC90 T5 AWD  SUV - STANDARD             2.0          4
# 7384  VOLVO  XC90 T6 AWD  SUV - STANDARD             2.0          4
#
#      Transmission Fuel Type  Fuel Consumption City (L/100 km)  \
# 7380          AS8         Z                              10.7
# 7381          AS8         Z                              11.2
# 7382          AS8         Z                              11.7
# 7383          AS8         Z                              11.2
# 7384          AS8         Z                              12.2
#
#       Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# 7380                              7.7                               9.4
# ...

# %%
#shape
df.shape
# Out:
# (7385, 12)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 7385 entries, 0 to 7384
# Data columns (total 12 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Make                              7385 non-null   str
#  1   Model                             7385 non-null   str
#  2   Vehicle Class                     7385 non-null   str
#  3   Engine Size(L)                    7385 non-null   float64
#  4   Cylinders                         7385 non-null   int64
#  5   Transmission                      7385 non-null   str
#  6   Fuel Type                         7385 non-null   str
#  7   Fuel Consumption City (L/100 km)  7385 non-null   float64
#  8   Fuel Consumption Hwy (L/100 km)   7385 non-null   float64
#  9   Fuel Consumption Comb (L/100 km)  7385 non-null   float64
#  10  Fuel Consumption Comb (mpg)       7385 non-null   int64
#  11  CO2 Emissions(g/km)               7385 non-null   int64
# ...

# %%
#finding missing values
df.isnull().sum()
# Out:
# Make                                0
# Model                               0
# Vehicle Class                       0
# Engine Size(L)                      0
# Cylinders                           0
# Transmission                        0
# Fuel Type                           0
# Fuel Consumption City (L/100 km)    0
# Fuel Consumption Hwy (L/100 km)     0
# Fuel Consumption Comb (L/100 km)    0
# Fuel Consumption Comb (mpg)         0
# CO2 Emissions(g/km)                 0
# dtype: int64

# %%
#finding duplicates
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 7380    False
# 7381    False
# 7382    False
# 7383    False
# 7384    False
# Length: 7385, dtype: bool

# %%
df.duplicated().sum()
# Out:
# np.int64(1103)

# %%
# Remove duplicate rows
df_cleaned = df.drop_duplicates()

# %%
df_cleaned
# Out:
#        Make        Model   Vehicle Class  Engine Size(L)  Cylinders  \
# 0     ACURA          ILX         COMPACT             2.0          4
# 1     ACURA          ILX         COMPACT             2.4          4
# 2     ACURA   ILX HYBRID         COMPACT             1.5          4
# 3     ACURA      MDX 4WD     SUV - SMALL             3.5          6
# 4     ACURA      RDX AWD     SUV - SMALL             3.5          6
# ...     ...          ...             ...             ...        ...
# 7380  VOLVO  XC40 T5 AWD     SUV - SMALL             2.0          4
# 7381  VOLVO  XC60 T5 AWD     SUV - SMALL             2.0          4
# 7382  VOLVO  XC60 T6 AWD     SUV - SMALL             2.0          4
# 7383  VOLVO  XC90 T5 AWD  SUV - STANDARD             2.0          4
# 7384  VOLVO  XC90 T6 AWD  SUV - STANDARD             2.0          4
#
#      Transmission Fuel Type  Fuel Consumption City (L/100 km)  \
# 0             AS5         Z                               9.9
# ...

# %%
df_cleaned.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 6282 entries, 0 to 7384
# Data columns (total 12 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Make                              6282 non-null   str
#  1   Model                             6282 non-null   str
#  2   Vehicle Class                     6282 non-null   str
#  3   Engine Size(L)                    6282 non-null   float64
#  4   Cylinders                         6282 non-null   int64
#  5   Transmission                      6282 non-null   str
#  6   Fuel Type                         6282 non-null   str
#  7   Fuel Consumption City (L/100 km)  6282 non-null   float64
#  8   Fuel Consumption Hwy (L/100 km)   6282 non-null   float64
#  9   Fuel Consumption Comb (L/100 km)  6282 non-null   float64
#  10  Fuel Consumption Comb (mpg)       6282 non-null   int64
#  11  CO2 Emissions(g/km)               6282 non-null   int64
# ...

# %%
# Verify that duplicates have been removed
print("Shape of the original DataFrame:", df.shape)
print("Shape of the DataFrame after removing duplicates:", df_cleaned.shape)
# Out:
# Shape of the original DataFrame: (7385, 12)
# Shape of the DataFrame after removing duplicates: (6282, 12)

# %%
# Get unique values for categorical columns (object type)
for col in df_cleaned.select_dtypes(include='object').columns:
    print(df_cleaned[col].value_counts)
    print("------"*10)
# Out:
# <bound method IndexOpsMixin.value_counts of 0       ACURA
# 1       ACURA
# 2       ACURA
# 3       ACURA
# 4       ACURA
#         ...
# 7380    VOLVO
# 7381    VOLVO
# 7382    VOLVO
# 7383    VOLVO
# 7384    VOLVO
# Name: Make, Length: 6282, dtype: str>
# ------------------------------------------------------------
# <bound method IndexOpsMixin.value_counts of 0               ILX
# 1               ILX
# 2        ILX HYBRID
# 3           MDX 4WD
# 4           RDX AWD
#            ...
# 7380    XC40 T5 AWD
# 7381    XC60 T5 AWD
# 7382    XC60 T6 AWD
# 7383    XC90 T5 AWD
# 7384    XC90 T6 AWD
# Name: Model, Length: 6282, dtype: str>
# ------------------------------------------------------------
# <bound method IndexOpsMixin.value_counts of 0              COMPACT
# 1              COMPACT
# 2              COMPACT
# 3          SUV - SMALL
# 4          SUV - SMALL
#              ...
# 7380       SUV - SMALL
# 7381       SUV - SMALL
# 7382       SUV - SMALL
# 7383    SUV - STANDARD
# ...

# %%
for col in df_cleaned.select_dtypes(exclude='object').columns:
    print(df_cleaned[col])
    print("------"*10)
# Out:
# 0       2.0
# 1       2.4
# 2       1.5
# 3       3.5
# 4       3.5
#        ...
# 7380    2.0
# 7381    2.0
# 7382    2.0
# 7383    2.0
# 7384    2.0
# Name: Engine Size(L), Length: 6282, dtype: float64
# ------------------------------------------------------------
# 0       4
# 1       4
# 2       4
# 3       6
# 4       6
#        ..
# 7380    4
# 7381    4
# 7382    4
# 7383    4
# 7384    4
# Name: Cylinders, Length: 6282, dtype: int64
# ------------------------------------------------------------
# 0        9.9
# 1       11.2
# 2        6.0
# 3       12.7
# 4       12.1
#         ...
# 7380    10.7
# 7381    11.2
# 7382    11.7
# 7383    11.2
# 7384    12.2
# Name: Fuel Consumption City (L/100 km), Length: 6282, dtype: float64
# ------------------------------------------------------------
# 0       6.7
# 1       7.7
# 2       5.8
# 3       9.1
# 4       8.7
#        ...
# 7380    7.7
# 7381    8.3
# 7382    8.6
# 7383    8.3
# 7384    8.7
# ...

# %%
# Get descriptive statistics for numerical columns to identify outliers
df_cleaned.describe().T
# Out:
#                                    count        mean        std   min    25%  \
# Engine Size(L)                    6282.0    3.161812   1.365201   0.9    2.0
# Cylinders                         6282.0    5.618911   1.846250   3.0    4.0
# Fuel Consumption City (L/100 km)  6282.0   12.610220   3.553066   4.2   10.1
# Fuel Consumption Hwy (L/100 km)   6282.0    9.070583   2.278884   4.0    7.5
# Fuel Consumption Comb (L/100 km)  6282.0   11.017876   2.946876   4.1    8.9
# Fuel Consumption Comb (mpg)       6282.0   27.411016   7.245318  11.0   22.0
# CO2 Emissions(g/km)               6282.0  251.157752  59.290426  96.0  208.0
#
#                                     50%    75%    max
# Engine Size(L)                      3.0    3.7    8.4
# Cylinders                           6.0    6.0   16.0
# Fuel Consumption City (L/100 km)   12.1   14.7   30.6
# Fuel Consumption Hwy (L/100 km)     8.7   10.3   20.6
# Fuel Consumption Comb (L/100 km)   10.6   12.7   26.1
# ...

# %%
df_cleaned.describe(include="object")
# Out:
# C:\Users\Sushanth\AppData\Local\Temp\ipykernel_3872\3445924455.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   df_cleaned.describe(include="object")
#         Make      Model Vehicle Class Transmission Fuel Type
# count   6282       6282          6282         6282      6282
# unique    42       2053            16           27         5
# top     FORD  F-150 FFV   SUV - SMALL          AS6         X
# freq     577         32          1006         1139      3039

# %%
df_cleaned.to_csv("../Datasets/CO2_Emissions_Cleaned.csv", index=False)

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df_cleaned, x='Engine Size(L)', y='CO2 Emissions(g/km)', palette='husl', hue='Cylinders')
plt.title('Scatter Plot of Engine Size vs. CO2 Emissions by Cylinders')
plt.xlabel('Engine Size(L)')
plt.ylabel('CO2 Emissions(g/km)')
# Out:
# Text(0, 0.5, 'CO2 Emissions(g/km)')

# %%
plt.figure(figsize=(8,5))
sns.boxplot(x='Fuel Type', y='CO2 Emissions(g/km)', data=df_cleaned, palette='Set2')
plt.title('CO₂ Emissions by Fuel Type', fontsize=14)
plt.xlabel('Fuel Type')
plt.ylabel('CO₂ Emissions (g/km)')
plt.show()
# Out:
# C:\Users\Sushanth\AppData\Local\Temp\ipykernel_3872\2046562494.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Fuel Type', y='CO2 Emissions(g/km)', data=df_cleaned, palette='Set2')

# %%
corr = df_cleaned[['Engine Size(L)', 'Cylinders', 'Fuel Consumption Comb (L/100 km)', 'CO2 Emissions(g/km)']].corr()
sns.heatmap(corr, annot=True,cmap='coolwarm')
plt.title('Correlation Matrix')
# Out:
# Text(0.5, 1.0, 'Correlation Matrix')
